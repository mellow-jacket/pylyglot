# %%
import os

os.chdir('..')

# %%
# %matplotlib widget
import ctpy as ct
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Use the API key
api_key = os.getenv('API_KEY')

# %%
test = ct.issue(
    name='issue199',
    url = 'https://newtoki319.com/webtoon/22501581',
    api_key=api_key
    )
test.make_pdf()

# %%
test.scrape()
# Out:
# Downloaded https://img1.newtoki20.org/data/file/webtoon/30125582/34285189/04oK_ZJnsmGH.jpg to c:\Users\16787\Desktop\projects\comic_translator\ctpy\..\raw_chapters\issue199\scraped_images\page_num_0.jpeg
# Downloaded https://img1.newtoki20.org/data/file/webtoon/24251/22501581/gAqzw09pxEcP.jpg to c:\Users\16787\Desktop\projects\comic_translator\ctpy\..\raw_chapters\issue199\scraped_images\page_num_1.jpeg
# Downloaded https://img1.newtoki20.org/data/file/webtoon/24251/22501581/G620bNm8PFnU.jpg to c:\Users\16787\Desktop\projects\comic_translator\ctpy\..\raw_chapters\issue199\scraped_images\page_num_2.jpeg
# Downloaded https://img1.newtoki20.org/data/file/webtoon/24251/22501581/7EKX0dF1lwB_.jpg to c:\Users\16787\Desktop\projects\comic_translator\ctpy\..\raw_chapters\issue199\scraped_images\page_num_3.jpeg
# ...

# %%
#test.clear_directories()

# %%
#ct.split_file('raw_chapters/issue199/raw_images/page_num_133.jpeg')
# Out:
# path is :  raw_chapters/issue199/raw_images/page_num_133.jpeg

# %%
#ct.separate_file('raw_chapters/issue199/raw_images/page_num_74.jpeg')
# Out:
# Image separated into two and files renamed successfully.

# %%
test.downsample(scale_factor=1.0)

# %%
test.combine_pages(110,111)

# %%
test.autobox(lang='kor')
# Out:
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# check refined boxes :  []
# ...

# %%
# Usage
drawer = ct.BoxDrawer(test)
drawer.draw()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Drawing mode: Enabled

# %%
test.perform_ocr_on_all_images()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test.add_boxes_to_images()

# %%
test.combine_gpt_and_ocr()

# %%
test.translate()

# %%
test.make_pdf()
